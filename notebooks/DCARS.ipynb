# %%
import gpxpy
import pandas as pnd
import numpy as np
from datetime import timedelta

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

# %load_ext autoreload
# %autoreload 2

# %matplotlib notebook
matplotlib.rcParams['axes.labelsize'] = 'large'
matplotlib.rcParams['ytick.labelsize'] = 'medium'
matplotlib.rcParams['xtick.labelsize'] = 'medium'
matplotlib.rcParams['figure.figsize'] = (4, 4)
sns.set_style('ticks', {"axes.xmargin": 0.2, "axes.ymargin": 0.2});

# %%
file = 'run_grenoble.csv'
#file = 'run_barcelona.csv'
trajectories = pnd.read_csv(file, index_col=0, parse_dates=True)
#path = r"C:\Users\Tales\Desktop\user54594328_traj1001316367.csv"
#df = pnd.read_csv(path, parse_dates=True, index_col='timestamp')
trajectories.head()
# Out:
#                      duration        length  n_points  \
# start_time
# 2015-01-08 03:04:24    8175.0  15929.962836      1440
# 2015-04-06 03:30:30    5240.0  12828.933976      1136
# 2015-04-10 05:33:06    2384.0   5399.799736       482
# 2015-04-21 01:19:41    6222.0  14362.928490      1284
# 2015-04-23 03:17:10    4872.0  12114.256493      1073
#
#                                                                   path  \
# start_time
# 2015-01-08 03:04:24  C:\DATA\MapMyRun\Grenoble\12589350\16_16_Run _...
# 2015-04-06 03:30:30  C:\DATA\MapMyRun\Grenoble\12589350\16_16_Run _...
# 2015-04-10 05:33:06  C:\DATA\MapMyRun\Grenoble\12589350\16_16_Run _...
# 2015-04-21 01:19:41  C:\DATA\MapMyRun\Grenoble\12589350\16_16_Run _...
# 2015-04-23 03:17:10  C:\DATA\MapMyRun\Grenoble\12589350\16_16_Run _...
#
#                                 source  trajectory_id   user_id
# start_time
# 2015-01-08 03:04:24  MapMyRun+ Android      836744489  12589350
# 2015-04-06 03:30:30  MapMyRun+ Android      931326825  12589350
# 2015-04-10 05:33:06  MapMyRun+ Android      936730399  12589350
# 2015-04-21 01:19:41  MapMyRun+ Android      951924889  12589350
# 2015-04-23 03:17:10  MapMyRun+ Android      954951663  12589350

# %%
len(trajectories)
# Out:
# 264

# %%
users = trajectories.groupby('user_id')

# %%
len(users)
# Out:
# 10

# %%
for user in users:
    print(user[0], len(user[1]))
# Out:
# 9875736 6
# 9909216 8
# 12589350 6
# 22901617 9
# 27031614 51
# 37695677 14
# 38534723 11
# 40890583 74
# 41837719 61
# 49996348 24

# %%
for user in users:
    print(user[0], len(user[1]))
    user_df = user[1]
    plt.figure()
    plt.subplot(211)
    sns.distplot(user_df.duration)
    plt.subplot(212)
    sns.distplot(user_df.length)
    plt.tight_layout()
# Out:
# 9875736 6
# <div id='22687d3f-1f64-4f24-943e-e89dccf07efd'></div>
# c:\users\tales\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# 9909216 8
# <div id='188452d5-5f40-4a7a-befb-49cfde39f88f'></div>
# 12589350 6
# <div id='af4ba7ca-2db5-41ac-ba65-fe220b4d323b'></div>
# 22901617 9
# <div id='701bfa83-b869-4d1b-8457-3c63e6a45be0'></div>
# 27031614 51
# <div id='39ae673a-a568-4191-8a3a-7f1806ab68b1'></div>
# 37695677 14
# <div id='994d0500-c49e-4ccb-a58b-b710aba9189f'></div>
# 38534723 11
# <div id='d5304ab3-a2f0-42d4-bd65-b087eb6f88c2'></div>
# 40890583 74
# <div id='d2653df7-ebfe-47f2-91f9-9451204b2374'></div>
# 41837719 61
# <div id='04009d8b-a245-4caa-a153-173bf4886ccb'></div>
# 49996348 24
# <div id='95f39ed1-77d4-4bbb-804f-6e5d9835e517'></div>
